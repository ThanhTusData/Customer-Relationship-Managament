# %% [markdown]
# # EDA

# %% [raw]
# dữ liệu từ tệp updated thiếu 1 cột, còn lại thì dữ liệu giống với tệp trends nên sẽ lấy tệp trend để thực hiện
#
# Customer ID: Định danh khách hàng, theo dõi lịch sử mua sắm.
# Age: Tuổi khách hàng, phân khúc và phân tích hành vi theo độ tuổi.
# Gender: Giới tính, phân tích sở thích theo nhóm giới tính.
# Item Purchased: Sản phẩm đã mua, phân tích sản phẩm phổ biến.
# Category: Loại sản phẩm, theo dõi xu hướng tiêu dùng.
# Purchase Amount (USD): Giá trị mua hàng, tính doanh thu và phân tích giá trị khách hàng.
# Location: Vị trí khách hàng, phân tích doanh số theo khu vực.
# Size: Kích thước sản phẩm, phân tích sở thích kích cỡ.
# Color: Màu sản phẩm, phân tích xu hướng màu sắc.
# Season: Mùa mua hàng, phân tích xu hướng thời điểm.
# Review Rating: Đánh giá sản phẩm, phân tích mức độ hài lòng.
# Subscription Status: Trạng thái đăng ký, phân tích khách hàng trung thành.
# Payment Method: Phương thức thanh toán, hiểu sở thích thanh toán.
# Shipping Type: Loại vận chuyển, phân tích lựa chọn giao hàng.
# Discount Applied: Áp dụng giảm giá, đánh giá hiệu quả khuyến mãi.
# Promo Code Used: Mã khuyến mãi, phân tích hành vi sử dụng ưu đãi.
# Previous Purchases: Số lần mua trước, đo lường giá trị khách hàng lâu dài.
# Preferred Payment Method: Phương thức thanh toán ưu tiên, tối ưu thanh toán.
# Frequency of Purchases: Tần suất mua sắm, theo dõi hành vi mua hàng.
#
# Customer Value
# Tác dụng: Đo lường giá trị khách hàng dựa trên tổng giá trị mua sắm (tích số lần mua và số tiền chi tiêu).
# Ứng dụng: Xác định giá trị dài hạn (LTV) của khách hàng.
#
# Average Frequency
# Tác dụng: Chuyển đổi tần suất mua sắm từ dạng mô tả (Weekly, Monthly,...) sang số ngày trung bình.
# Ứng dụng: Đánh giá thói quen mua sắm của khách hàng.
#
# Category_Season
# Tác dụng: Kết hợp loại sản phẩm và mùa mua sắm thành một đặc trưng mới.
# Ứng dụng: Tìm hiểu sản phẩm nào được ưa chuộng theo mùa.
#
# Log Review Rating
# Tác dụng: Chuyển đổi đánh giá sản phẩm thành dạng logarit để giảm tác động của giá trị cao.
# Ứng dụng: Cải thiện hiệu suất mô hình bằng cách làm mịn phân phối dữ liệu.
#
# Exponential_Review
# Tác dụng: Nâng đánh giá sản phẩm lên bình phương để nhấn mạnh sự khác biệt ở các giá trị cao.
# Ứng dụng: Phát hiện các mẫu đặc biệt từ khách hàng có đánh giá cao vượt trội.
#
# Age_Rating_Interaction
# Tác dụng: Tương tác giữa tuổi và đánh giá sản phẩm, thể hiện cách các nhóm tuổi khác nhau đánh giá sản phẩm.
# Ứng dụng: Phân tích hành vi đánh giá sản phẩm theo độ tuổi.
#
# Subscription_Promo_Interaction
# Tác dụng: Đặc trưng tổ hợp cho thấy liệu khách hàng vừa có đăng ký vừa sử dụng mã khuyến mãi hay không.
# Ứng dụng: Phân tích mức độ quan tâm đến chương trình ưu đãi.
#
# Log Purchase Amount
# Tác dụng: Chuyển đổi giá trị mua sắm sang logarit để giảm tác động của các giao dịch giá trị cao.
# Ứng dụng: Tăng độ ổn định trong các mô hình học máy.
#
# Discount Rate
# Tác dụng: Biến nhị phân đại diện cho tỷ lệ giảm giá (10% nếu được áp dụng).
# Ứng dụng: Đo lường tác động của giảm giá đến doanh số.
#
# Effective Purchase Amount
# Tác dụng: Giá trị mua sắm sau khi trừ giảm giá (giá trị thực tế).
# Ứng dụng: Phân tích doanh thu thực tế.
#
# Payment_Match
# Tác dụng: Kiểm tra sự trùng khớp giữa phương thức thanh toán ưu tiên và phương thức thanh toán thực tế.
# Ứng dụng: Đánh giá trải nghiệm khách hàng.

# %% [markdown]
# # MODEL

# %% [raw]
# Mục tiêu 1: Tối đa hóa lợi nhuận từ các chiến dịch tiếp thị
# Mục tiêu này nhằm tối ưu hóa các chiến dịch tiếp thị bằng cách phân tích và hiểu điểm yếu của khách hàng để tạo ra các chiến dịch có sức ảnh hưởng mạnh mẽ hơn.
#
# RandomForestRegressor được sử dụng để tối đa hóa lợi nhuận từ các chiến dịch tiếp thị vì:
# Phù hợp với bài toán hồi quy: Dự đoán các giá trị liên tục như lợi nhuận, chi tiêu, hoặc giá trị kỳ vọng của khách hàng.
# Xử lý tốt dữ liệu phức tạp: Quản lý mối quan hệ phi tuyến tính và tự động phát hiện tương tác giữa các đặc trưng.
# Hiệu suất cao và giảm overfitting: Kết hợp nhiều cây quyết định giúp tăng độ chính xác và tính ổn định.
# Tính giải thích: Cung cấp thông tin về mức độ ảnh hưởng của các yếu tố đến lợi nhuận.
# Ứng dụng thực tiễn: Phân tích hành vi khách hàng, tối ưu ngân sách tiếp thị, và cá nhân hóa chiến dịch dựa trên dự đoán.
# Công cụ này hỗ trợ hiệu quả trong việc hiểu và tối ưu hóa các chiến dịch tiếp thị để gia tăng lợi nhuận.
#
# 1.Xử lý dữ liệu (Data Preprocessing)
# Điền giá trị thiếu: Điền các giá trị thiếu trong cột Average Frequency bằng giá trị trung bình của cột này.
# Mã hóa dữ liệu phân loại:
# Sử dụng LabelEncoder để chuyển đổi các cột phân loại như Item Purchased, Category, Color, v.v. thành các giá trị số.
# Phân tách dữ liệu:
# Chia dữ liệu thành biến đầu vào (X) và đầu ra (y), trong đó biến dự đoán là Customer Value.
# Loại bỏ các cột không liên quan như Customer ID.
# Chuẩn hóa dữ liệu:
# Sử dụng StandardScaler để chuẩn hóa các đặc trưng, đảm bảo rằng chúng có phân phối chuẩn (mean = 0, std = 1).
# 2.Huấn luyện mô hình (Model Training with Hyperparameter Tuning)
# Tìm kiếm siêu tham số (Grid Search):
# Tạo lưới các giá trị siêu tham số như n_estimators, max_depth, min_samples_split, và min_samples_leaf.
# Dùng GridSearchCV để tìm tổ hợp siêu tham số tối ưu bằng cách sử dụng RandomForestRegressor.
# Đánh giá mô hình bằng chỉ số lỗi trung bình bình phương (MSE).
# Huấn luyện mô hình: Huấn luyện mô hình Random Forest với các siêu tham số tối ưu tìm được từ GridSearchCV.
# 3.Đánh giá mô hình (Evaluation)
# Dự đoán: Sử dụng mô hình tối ưu để dự đoán giá trị khách hàng trên tập kiểm tra.
# Tính toán lỗi:
# MSE: Đánh giá độ lệch trung bình bình phương giữa giá trị thực tế và giá trị dự đoán.
# MAE: Đánh giá độ lệch tuyệt đối trung bình giữa giá trị thực tế và giá trị dự đoán.
# Xuất kết quả: In ra lỗi MSE, MAE và các siêu tham số tối ưu.
# 4.Khai thác thông tin chi tiết bằng SHAP (Customer Insights Using SHAP)
# Giải thích mô hình:
# Sử dụng SHAP để tính toán giá trị SHAP, cho phép hiểu các đặc trưng nào đóng vai trò quan trọng trong việc dự đoán.
# Biểu đồ tóm tắt: Vẽ biểu đồ tóm tắt SHAP để xác định các đặc trưng chính ảnh hưởng đến giá trị khách hàng.
# 5.Phân khúc khách hàng và đề xuất chiến lược (Actionable Insights for Marketing Campaigns)
# Phân khúc khách hàng:
# Chia khách hàng thành 4 nhóm dựa trên giá trị dự đoán: Low, Medium, High, và Premium thông qua phân vị (qcut).
# Phân tích nhóm:
# Tính trung bình các đặc trưng của từng nhóm để hiểu hành vi và đặc điểm khách hàng.
# Chiến lược marketing:
# Đề xuất các chiến lược phù hợp cho từng nhóm:
# Low: Giữ chân khách hàng với các ưu đãi, giảm giá.
# Medium: Thúc đẩy chương trình khách hàng thân thiết.
# High: Bán thêm các sản phẩm bổ sung.
# Premium: Cung cấp dịch vụ độc quyền.
# Tóm lại:
# Đoạn code thực hiện toàn bộ quy trình từ xử lý dữ liệu, xây dựng mô hình, giải thích kết quả, đến phân khúc khách hàng và đề xuất chiến lược marketing.
#
# Mục tiêu 2: Cải thiện khả năng giữ chân khách hàng
# Mục tiêu này nhằm giảm tỷ lệ khách hàng rời bỏ bằng cách phân tích các yếu tố quyết định và can thiệp kịp thời để giữ chân khách hàng.
#
# RandomForestClassifier được sử dụng để cải thiện khả năng giữ chân khách hàng vì:
# Phù hợp với bài toán phân loại: Phân loại khách hàng có khả năng rời bỏ hoặc không.
# Xử lý dữ liệu phức tạp: Hiệu quả với các đặc trưng đa dạng và phi tuyến tính.
# Giảm overfitting: Kết hợp nhiều cây quyết định giúp tổng quát hóa tốt.
# Tính giải thích cao: Xác định yếu tố chính dẫn đến churn.
# Hiệu suất cao: Xử lý tốt dữ liệu lớn và mất cân bằng, đặc biệt khi kết hợp với SMOTE.
# Ứng dụng thực tiễn: Dự đoán sớm và hỗ trợ chiến lược giữ chân khách hàng hiệu quả.
# Kết quả: Phát hiện khách hàng có nguy cơ rời bỏ và tối ưu hóa các chiến lược giữ chân.
#
# 1. Tiền xử lý dữ liệu (Data Preprocessing):
# Xử lý giá trị thiếu:
# Điền giá trị thiếu trong các cột số bằng giá trị trung vị (median).
# Mã hóa dữ liệu phân loại:
# Sử dụng LabelEncoder để chuyển các cột phân loại (như Gender, Item Purchased, Category,...) thành dạng số.
# Chuẩn hóa dữ liệu:
# Sử dụng StandardScaler để chuẩn hóa tất cả các cột đặc trưng (trừ cột Customer ID và Subscription Status), đảm bảo dữ liệu có phân phối chuẩn.
# Tách dữ liệu:
# Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra với tỷ lệ 80%-20%.
# 2. Huấn luyện mô hình và tìm siêu tham số tối ưu (Model Training and Hyperparameter Tuning):
# Thiết lập Grid Search:
# Khám phá các giá trị tối ưu cho các siêu tham số như n_estimators, max_depth, min_samples_split, và min_samples_leaf.
# Đo lường hiệu quả của mô hình qua chỉ số ROC-AUC.
# Huấn luyện mô hình:
# Tìm mô hình tốt nhất bằng cách thực hiện kiểm tra chéo (cv=3) trên tập huấn luyện.
# 3. Đánh giá mô hình (Model Evaluation):
# Dự đoán:
# Dự đoán nhãn và xác suất rời bỏ của khách hàng trên tập kiểm tra.
# Báo cáo chi tiết:
# Báo cáo phân loại: Đưa ra các chỉ số như Precision, Recall, F1-score.
# Ma trận nhầm lẫn: Hiển thị số lượng dự đoán đúng/sai giữa các nhãn "Retained" và "Churn".
# Đường cong ROC và Precision-Recall:
# Vẽ các đường cong ROC và Precision-Recall để trực quan hóa hiệu suất của mô hình.
# Tầm quan trọng của đặc trưng (Feature Importance):
# Đánh giá mức độ quan trọng của các đặc trưng trong việc dự đoán rời bỏ.
# 4. Phân loại và phân tích khách hàng (Customer Classification and Analysis):
# Tính xác suất rời bỏ:
# Thêm cột Churn_Probability để lưu xác suất khách hàng rời bỏ dự đoán bởi mô hình.
# Phân loại khách hàng rủi ro cao:
# Lọc ra các khách hàng có xác suất rời bỏ lớn hơn 0.7 và hiển thị thông tin của họ.
# 5. Gợi ý chiến lược giữ chân khách hàng (Intervention Suggestions):
# Đưa ra các biện pháp cụ thể:
# Cung cấp giảm giá hoặc dịch vụ miễn phí cho khách hàng có rủi ro rời bỏ cao.
# Tập trung cải thiện dịch vụ hoặc giải quyết khiếu nại.
# Phát triển các chương trình khách hàng thân thiết để duy trì sự trung thành.
# Trực quan hóa:
# Ma trận nhầm lẫn: Giúp đánh giá khả năng dự đoán chính xác các nhãn.
# Đường cong ROC và Precision-Recall: Đo lường hiệu quả mô hình trên các ngưỡng khác nhau.
# Feature Importance: Hiển thị top 10 đặc trưng quan trọng nhất ảnh hưởng đến quyết định rời bỏ.
# Ý nghĩa ứng dụng thực tế:
# Cung cấp một cách tiếp cận toàn diện để phân tích hành vi rời bỏ khách hàng, từ đó đưa ra các chiến lược giữ chân khách hàng một cách hiệu quả.
#
# Mục tiêu 3: Tối đa hóa giá trị khách hàng (bán chéo, bán thêm)
# Mục tiêu này nhằm tăng doanh thu từ mỗi khách hàng thông qua việc bán thêm hoặc bán chéo các sản phẩm dựa trên phân tích dữ liệu khách hàng.
#
# RandomForestRegressor được dùng cho Mục tiêu 3: Tối đa hóa giá trị khách hàng vì nó:
# Dự đoán giá trị liên tục như doanh thu từ bán chéo và bán thêm.
# Xử lý mối quan hệ phức tạp và không tuyến tính giữa các đặc trưng và mục tiêu.
# Chịu đựng tốt dữ liệu thiếu và nhiễu.
# Tăng khả năng tổng quát, tránh overfitting.
# Đánh giá tầm quan trọng của các đặc trưng, giúp tối ưu chiến lược bán hàng.
# Hỗ trợ tối đa hóa lợi nhuận từ mỗi khách hàng thông qua dự đoán chính xác.
#
# 1. Tiền xử lý dữ liệu
# Xử lý giá trị thiếu: Điền giá trị thiếu trong cột Average Frequency bằng trung bình.
# Mã hóa cột phân loại: Sử dụng LabelEncoder để mã hóa các cột có kiểu dữ liệu phân loại, lưu trữ các bộ mã hóa để sử dụng lại nếu cần.
# Chuẩn hóa dữ liệu: Dùng StandardScaler để chuẩn hóa tất cả các đặc trưng.
# 2. Huấn luyện mô hình cơ bản
# Sử dụng RandomForestRegressor làm mô hình ban đầu để dự đoán giá trị khách hàng.
# Đánh giá hiệu năng thông qua các chỉ số:
# MSE (Mean Squared Error)
# MAE (Mean Absolute Error)
# R2 Score
# 3. Tối ưu hóa mô hình với Grid Search
# Sử dụng GridSearchCV để tối ưu hóa các tham số của RandomForestRegressor, bao gồm:
# n_estimators: Số cây trong rừng.
# max_depth: Độ sâu tối đa của cây.
# min_samples_split: Số lượng mẫu tối thiểu để chia một nút.
# min_samples_leaf: Số lượng mẫu tối thiểu tại một lá.
# Trích xuất và đánh giá mô hình tốt nhất.
# 4. Phân tích và trực quan hóa
# Quan trọng của đặc trưng: Phân tích các đặc trưng đóng vai trò quan trọng nhất trong dự đoán.
# Phân tích lỗi: Trực quan hóa phân phối của phần dư để kiểm tra các sai lệch hệ thống trong dự đoán.
# Phân tích khách hàng giá trị cao: Lọc ra các khách hàng có giá trị dự đoán cao nhất (top 10%) để đưa ra chiến lược tập trung.
# 5. Gợi ý biện pháp
# Tập trung giữ chân các khách hàng có giá trị cao với các ưu đãi được cá nhân hóa.
# Dựa vào các đặc trưng quan trọng để tối ưu hóa các chiến lược marketing và dịch vụ.
# Liên tục dự đoán và điều chỉnh chiến lược để tăng giá trị khách hàng.
#
# Mục tiêu 4: Xác định và làm hài lòng những khách hàng có giá trị cao
# Mục tiêu này nhằm xác định và tạo sự hài lòng cho các khách hàng có giá trị cao để tối đa hóa lợi nhuận.
#
# GradientBoostingClassifier được sử dụng cho Mục tiêu 4: Xác định và làm hài lòng những khách hàng có giá trị cao vì:
# Phân loại chính xác: Giúp phân loại khách hàng thành nhóm "có giá trị cao" và "có giá trị thấp".
# Hiệu suất mạnh mẽ: Kết hợp nhiều cây quyết định để cải thiện độ chính xác trong việc phân loại khách hàng.
# Xử lý dữ liệu phức tạp: Có khả năng mô hình hóa mối quan hệ không tuyến tính giữa các yếu tố.
# Xử lý mất cân bằng: Tốt trong việc phân loại khi dữ liệu không cân bằng.
# Chọn đặc trưng quan trọng: Cung cấp thông tin về các yếu tố quan trọng trong việc xác định khách hàng có giá trị cao.
# Tối ưu lợi nhuận: Giúp tối đa hóa lợi nhuận bằng cách xác định và làm hài lòng khách hàng giá trị cao.
#
# 1. Tiền xử lý dữ liệu
# Xử lý giá trị thiếu: Điền giá trị trung bình vào cột Average Frequency nếu bị thiếu.
# Lựa chọn đặc trưng: Lấy danh sách các đặc trưng ban đầu để xây dựng mô hình.
# Chuẩn hóa dữ liệu: Dùng StandardScaler để chuẩn hóa dữ liệu.
# Xử lý mất cân bằng dữ liệu: Áp dụng SMOTE để cân bằng lại số lượng dữ liệu giữa hai nhóm (giá trị cao và giá trị thấp).
# 2. Chọn đặc trưng quan trọng
# Sử dụng RFE (Recursive Feature Elimination) với mô hình Gradient Boosting để chọn ra 10 đặc trưng quan trọng nhất.
# 3. Chia dữ liệu
# Tách dữ liệu thành tập huấn luyện và kiểm tra với tỷ lệ 80:20.
# 4. Tìm tham số tối ưu
# Áp dụng GridSearchCV để tìm các tham số tốt nhất cho mô hình Gradient Boosting (như số lượng cây, tốc độ học, độ sâu cây,...).
# Sử dụng StratifiedKFold để đảm bảo dữ liệu huấn luyện được chia đều cho các nhóm.
# 5. Đánh giá mô hình
# Cross-validation: Đánh giá mô hình bằng điểm ROC-AUC trên tập huấn luyện.
# Đánh giá trên tập kiểm tra: Tính điểm ROC-AUC, ma trận nhầm lẫn, và báo cáo phân loại.
# Trực quan hóa: Vẽ đường cong ROC để minh họa hiệu suất mô hình.
# 6. Phân tích đặc trưng quan trọng
# Lấy ra và trực quan hóa tầm quan trọng của các đặc trưng dựa trên mô hình tốt nhất.
# 7. Dự đoán khách hàng giá trị cao
# Sử dụng mô hình tốt nhất để dự đoán khách hàng giá trị cao từ toàn bộ tập dữ liệu ban đầu.
# Lưu danh sách khách hàng giá trị cao vào file CSV (high_value_customers.csv) để sử dụng cho các chiến dịch kinh doanh.
# Mục tiêu của quy trình:
# Phân loại chính xác khách hàng giá trị cao để hỗ trợ xây dựng các chiến lược tiếp thị và chăm sóc khách hàng.
# Tăng hiệu suất dự đoán thông qua xử lý dữ liệu, chọn đặc trưng và tối ưu hóa mô hình.
# Trực quan hóa và phân tích các yếu tố ảnh hưởng đến giá trị khách hàng.
#
# Mục tiêu 5: Quản lý hình ảnh thương hiệu
# Mục tiêu này nhằm hiểu và cải thiện hình ảnh thương hiệu thông qua phân tích tình cảm của khách hàng và các phản hồi trên mạng xã hội.
#
# GradientBoostingClassifier được sử dụng cho Mục tiêu 5: Quản lý hình ảnh thương hiệu vì:
# Phân loại tình cảm: Dự đoán cảm xúc của khách hàng (tích cực, tiêu cực, trung lập) từ phản hồi và bình luận.
# Xử lý dữ liệu phức tạp: Mô hình mạnh mẽ trong việc phát hiện mối quan hệ phi tuyến tính giữa các đặc trưng.
# Cải thiện độ chính xác: Kết hợp nhiều cây quyết định để cải thiện dự đoán tình cảm.
# Xử lý mất cân bằng: Hiệu quả với dữ liệu không cân bằng (ví dụ: ít phản hồi tiêu cực hơn tích cực).
# Điều chỉnh đặc trưng: Lựa chọn đặc trưng quan trọng, như từ khóa trong bình luận, giúp phân tích yếu tố tác động đến hình ảnh thương hiệu.
# Tối ưu hóa chiến lược: Giúp doanh nghiệp cải thiện và duy trì hình ảnh thương hiệu dựa trên phân tích tình cảm khách hàng.
#
# 1. Xử lý dữ liệu
# Tạo nhãn cảm xúc: Chuyển đổi cột Review Rating thành nhãn Sentiment:
# 1 nếu Rating > 3 (Cảm xúc tích cực).
# 0 nếu Rating ≤ 3 (Cảm xúc tiêu cực).
# Chọn đặc trưng đầu vào: Gồm các thông tin liên quan như độ tuổi, giới tính, sản phẩm đã mua, giá trị đơn hàng, mã giảm giá, phương thức thanh toán,...
# Xử lý dữ liệu phân loại:
# Sử dụng LabelEncoder để chuyển đổi các cột dạng phân loại (categorical) thành số.
# Chuẩn hóa dữ liệu số:
# Chuẩn hóa các cột như Age, Purchase Amount (USD), Previous Purchases bằng StandardScaler.
# 2. Xử lý mất cân bằng dữ liệu
# Áp dụng SMOTE (Synthetic Minority Oversampling Technique) để cân bằng số lượng giữa hai nhóm cảm xúc (0: Tiêu cực, 1: Tích cực).
# 3. Chia dữ liệu
# Chia dữ liệu thành tập huấn luyện (80%) và kiểm tra (20%).
# 4. Huấn luyện mô hình
# Sử dụng GradientBoostingClassifier:
# Thực hiện đánh giá mô hình qua cross-validation (5-fold), tính điểm accuracy trung bình.
# Tối ưu tham số:
# Áp dụng GridSearchCV để tìm bộ tham số tốt nhất (n_estimators, max_depth, learning_rate, min_samples_split, min_samples_leaf).
# 5. Đánh giá mô hình
# Đánh giá trên tập kiểm tra:
# Tính độ chính xác (accuracy).
# Báo cáo phân loại (classification report) với các chỉ số như Precision, Recall, F1-Score.
# Kết quả đầu ra
# Điểm accuracy trung bình từ cross-validation.
# Bộ tham số tốt nhất từ GridSearchCV.
# Độ chính xác (Optimized Accuracy) và báo cáo chi tiết hiệu suất của mô hình tối ưu trên tập kiểm tra.
# Ý nghĩa ứng dụng
# Mô hình này giúp doanh nghiệp hiểu rõ hơn về phản hồi của khách hàng, từ đó có thể:
# Cải thiện sản phẩm/dịch vụ dựa trên cảm xúc tiêu cực.
# Xác định khách hàng hài lòng để duy trì mối quan hệ lâu dài.
# Hỗ trợ phân tích các yếu tố ảnh hưởng đến cảm xúc khách hàng.
